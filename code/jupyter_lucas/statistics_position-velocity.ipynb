# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
idx = pd.IndexSlice

# %%
vp = r'C:\Users\b1090197\OneDrive\Documents\XSki\xski\files\position_data.csv'
pp = r'C:\Users\b1090197\OneDrive\Documents\XSki\xski\files\velocity_data.csv'

v = pd.read_csv(vp, header=[0,1], index_col=[0])
v.columns.rename("Participant", level=0, inplace=True)
v.columns.rename("Intensity", level=1, inplace=True)

p = pd.read_csv(pp, header=[0,1], index_col=[0])
p.columns.rename("Participant", level=0, inplace=True)
p.columns.rename("Intensity", level=1, inplace=True)

# %%
v.describe()
# Out:
# Participant          P3                                  P5              \
# Intensity          easy        hard      medium        easy        hard
# count        101.000000  101.000000  101.000000  101.000000  101.000000
# mean          11.427878   12.313362   12.787751   22.943139   29.956792
# std            7.262879    8.232122    7.618270    6.982824    7.402600
# min            1.701250    0.357861    0.226331    7.589684    1.154066
# 25%            5.171056    4.898902    5.781416   18.756816   26.743951
# 50%           11.299561   11.451542   12.484158   23.621516   31.020556
# 75%           15.034408   17.616053   17.181040   28.059563   35.217927
# max           35.195011   34.976739   35.056102   38.569679   42.299677
#
# Participant                      P6                                  P7  \
# Intensity        medium        easy        hard      medium        easy
# count        101.000000  101.000000  101.000000  101.000000  101.000000
# mean          27.571128   22.361991   30.586322   26.230027   16.318937
# std            6.461983    7.634209   11.652696    9.107854    7.034364
# min           11.709210    4.309213    3.220746    3.509955    4.309213
# 25%           24.412814   17.862948   22.905879   20.755919   12.167263
# 50%           29.140496   21.629118   32.296802   26.278770   15.034408
# 75%           31.783186   27.699434   39.152313   31.958782   19.483534
# max           40.078479   39.939881   48.605069   44.029372   44.667263
#
# Participant                                 P12                          \
# Intensity          hard      medium        easy        hard      medium
# count        101.000000  101.000000  101.000000  101.000000  101.000000
# mean          22.694534   20.414891   11.974025   13.809240   13.632467
# std            6.609785    6.682708    6.172235    7.369267    6.331378
# min            5.053317    7.106936    1.723685    2.937947    1.319725
# 25%           19.039399   15.622576    8.603554    9.183851   10.592918
# 50%           22.556580   19.850787   11.960258   12.268934   12.456431
# 75%           26.715204   25.067112   15.030148   17.822755   16.004016
# max           39.265650   36.467390   32.774255   33.377487   33.845751
#
# Participant         P13
# Intensity          easy        hard      medium
# count        101.000000  101.000000  101.000000
# mean          21.433803   26.112695   23.972442
# std            7.932243    7.071232    7.016452
# min            0.452662    1.946973    9.323627
# 25%           15.779181   20.774421   18.966616
# 50%           21.688247   27.777458   24.104513
# 75%           26.689786   29.933928   28.214767
# max           39.633131   40.217236   40.209593

# %%
p.describe()
# Out:
# Participant          P3                                  P5              \
# Intensity          easy        hard      medium        easy        hard
# count        101.000000  101.000000  101.000000  101.000000  101.000000
# mean         374.346369  377.032415  350.710822  384.730881  392.310116
# std          223.039196  226.310540  207.879726  241.922706  244.008333
# min            0.000000    0.000000    0.000000    0.000000    0.000000
# 25%          222.553987  223.233085  198.765596  178.151682  185.606761
# 50%          348.208300  377.710073  322.130925  371.696028  391.015274
# 75%          516.895920  524.201318  501.899923  583.635992  596.012949
# max          786.937144  758.659307  751.907492  797.360693  809.463611
#
# Participant                      P6                                  P7  \
# Intensity        medium        easy        hard      medium        easy
# count        101.000000  101.000000  101.000000  101.000000  101.000000
# mean         372.932455  395.008996  420.701164  403.313273  394.850036
# std          232.545464  236.213898  247.325436  245.185275  239.696044
# min            0.000000    0.000000    0.000000    0.000000    0.000000
# 25%          175.720438  200.563634  215.779689  193.961695  205.587029
# 50%          366.268981  395.426210  432.951913  405.789300  394.822275
# 75%          562.810874  610.979856  667.030710  643.145397  591.512152
# max          772.232676  775.691307  780.923635  780.893672  796.184907
#
# Participant                                 P12                          \
# Intensity          hard      medium        easy        hard      medium
# count        101.000000  101.000000  101.000000  101.000000  101.000000
# mean         392.417484  393.059399  386.628769  378.919593  387.468518
# std          234.640164  239.728564  228.768294  222.101216  229.345590
# min            0.000000    0.000000    0.000000    0.000000    0.000000
# 25%          207.393161  197.083946  216.547667  213.679669  209.393012
# 50%          394.309558  392.832081  387.281435  381.794854  394.097038
# 75%          579.886572  591.666792  535.819977  530.560209  551.242319
# max          789.238022  795.959198  788.524473  785.057241  783.781330
#
# Participant         P13
# Intensity          easy        hard      medium
# count        101.000000  101.000000  101.000000
# mean         369.685714  364.592276  368.611425
# std          233.822637  227.937280  229.732920
# min            0.000000    0.000000    0.000000
# 25%          173.928209  173.389375  173.468757
# 50%          352.299203  355.263940  363.780685
# 75%          549.113765  545.833123  554.995691
# max          771.077453  755.214590  755.410486

# %%
# example slice
v.loc[:,idx[:,'medium']].plot()
# Out:
# <AxesSubplot:>

# %%
v['P3']['easy'].plot(color="g", linewidth = 2)
v['P3']['medium'].plot(color="b", linewidth = 2)
v['P3']['hard'].plot(color="r", linewidth = 2)
plt.legend()

# %%
fig, ax = plt.subplots(1,1)
ax.plot(v.loc[:,idx["P3","easy"]], color="g", label="easy")
ax.plot(v.loc[:,idx["P3","medium"]], color="b", label="medium")
ax.plot(v.loc[:,idx["P3","hard"]], color="r", label="hard")
ax.legend()
v.loc[:,idx[:,"easy"]].plot(color="g", ax=ax, legend=False)
v.loc[:,idx[:,"medium"]].plot(color="b", ax=ax, legend=False)
v.loc[:,idx[:,"hard"]].plot(color="r", ax=ax, legend=False)
ax.set_ylabel("v [km/h]")
ax.set_title('hello')
# Out:
# Text(0.5, 1.0, 'hello')

# %%
p=p.T
p
# Out:
# Participant          P3                                  P5              \
# Intensity          easy        hard      medium        easy        hard
# 0              0.000000    0.000000    0.000000    0.000000    0.000000
# 1              4.265030    1.050414    4.718856    3.317280    0.504530
# 2             10.103524    3.911208   10.582216    8.011003    2.446607
# 3             16.614416    7.120494   16.753222   13.450393    6.585766
# 4             24.394563   13.032979   23.013722   19.229176   10.818611
# ..                  ...         ...         ...         ...         ...
# 96           753.432839  731.777750  712.226343  766.384012  776.087984
# 97           762.151279  736.319620  722.930815  774.170515  784.542058
# 98           771.424529  742.092729  732.529846  781.991109  793.043656
# 99           779.637514  750.217203  742.975752  789.825536  801.471350
# 100          786.937144  758.659307  751.907492  797.360693  809.463611
#
# Participant                      P6                                  P7  \
# Intensity        medium        easy        hard      medium        easy
# 0              0.000000    0.000000    0.000000    0.000000    0.000000
# 1              4.075910    5.194750    2.083638    2.450723    3.058086
# 2              8.685344   11.182034    6.958626    6.921842    8.060172
# 3             13.830910   17.542731   11.486590   12.021490   13.893902
# 4             18.920037   23.747045   18.111073   19.081842   20.191006
# ..                  ...         ...         ...         ...         ...
# 96           741.385578  746.499625  748.619474  750.556127  770.470575
# 97           749.008206  752.555172  756.405746  757.213376  778.738745
# 98           756.694471  760.301228  764.954679  764.353559  785.412482
# 99           764.391214  768.075848  771.748298  773.466238  791.423614
# 100          772.232676  775.691307  780.923635  780.893672  796.184907
#
# Participant                                 P12                          \
# Intensity          hard      medium        easy        hard      medium
# 0              0.000000    0.000000    0.000000    0.000000    0.000000
# 1              2.855395    3.914359    6.462744    6.874979    5.975880
# 2              6.657303    9.499028   13.170048   14.925400   13.377707
# 3             12.730137   14.697253   19.000357   23.205467   21.262243
# 4             19.229796   21.123089   25.460522   30.313685   29.346275
# ..                  ...         ...         ...         ...         ...
# 96           759.420050  767.720734  755.908077  750.776206  752.292043
# 97           766.344549  775.488022  764.870717  760.342442  760.606392
# 98           773.924345  783.433426  773.352284  768.952794  769.485799
# 99           781.632702  789.642228  782.583119  777.303949  777.415391
# 100          789.238022  795.959198  788.524473  785.057241  783.781330
#
# Participant         P13
# Intensity          easy        hard      medium
# 0              0.000000    0.000000    0.000000
# 1              0.621799    1.240047    3.495465
# 2              4.087957    5.190649    9.037513
# 3              8.898127    9.442629   13.553511
# 4             14.213705   15.835906   19.352272
# ..                  ...         ...         ...
# 96           742.325070  729.035492  727.629004
# 97           750.856816  735.351804  734.759619
# 98           757.676937  742.080913  740.365780
# 99           764.448113  748.826670  747.848358
# 100          771.077453  755.214590  755.410486
#
# [101 rows x 18 columns]

# %%
sns.relplot(data=p.loc[:,idx[:,'hard']], height=5, aspect=2.2, kind='line')
#plt.title('Position')
#plt.xlabel('[% Track]')
#plt.ylabel('Distance Traveled [m]')

# %%
sns.relplot(data=v.loc[:,idx[:,'hard']], height=5, aspect=2.2, kind='line')
plt.title('Velocity Profile')
plt.xlabel('[% Track]')
plt.ylabel('Veleocity [km/h]')
# Out:
# Text(23.87968750000001, 0.5, 'Veleocity [km/h]')

# %%
sns.relplot(data=v['P13'], height=5, aspect=2.2, kind='line')

# %% [markdown]
# ## relative Velocity

# %%
participants = 
p13 = v['P13']['medium'].values
sns.relplot(data=v['P13'].apply(lambda x: x- p13, axis=0), height=5, aspect=2.2, kind='line')

# %%
p6 = v['P5']['medium'].values
sns.relplot(data=v.loc[:,idx[:,'medium']].apply(lambda x: x- p6, axis=0), height=5, aspect=2.2, kind='line')
