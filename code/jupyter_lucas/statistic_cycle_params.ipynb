# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
idx = pd.IndexSlice
sns.set_style("darkgrid")

# %%
fp = r'C:\Users\b1090197\OneDrive\Documents\XSki\xski\files\cycle_temp_params.csv'

df=pd.read_csv(fp, index_col=[1,2], header=[0])
df.index.rename("participant", level=0, inplace=True)
df.index.rename("intensity", level=1, inplace=True)
df=df[df.columns[1:]]

# %%
df
# Out:
#                         subtech  start_frame  stop_frame  cycle_time  \
# participant intensity
# P3          easy             dp         2459        2879    1.750000
#             easy             dp         2879        3316    1.820833
#             easy             dp         3316        3721    1.687500
#             easy             dp         3721        4141    1.750000
#             easy             dp         4141        4483    1.425000
# ...                         ...          ...         ...         ...
# P14         hard       dp-skate        15205       15460    1.062500
#             hard       dp-skate        16435       16853    1.741667
#             hard       dp-skate        18063       18275    0.883333
#             hard       dp-skate        18275       18481    0.858333
#             hard       dp-skate        18481       18678    0.820833
#
#                        cycle_distance  cycle_speed
# participant intensity
# P3          easy             5.377489    11.062262
#             easy             5.560258    10.993279
#             easy             4.549126     9.704802
#             easy             5.137541    10.568656
#             easy             4.278466    10.808757
# ...                               ...          ...
# P14         hard             0.000000     0.000000
#             hard             0.000000     0.000000
#             hard             0.000000     0.000000
#             hard             0.000000     0.000000
#             hard             0.000000     0.000000
#
# [2280 rows x 6 columns]

# %%
sns.relplot(data=df.loc['P6','hard'], x='start_frame', y='cycle_distance', hue = 'subtech', aspect=2)
# Out:
# C:\Users\b1090197\AppData\Local\Temp\ipykernel_18912\3756123833.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   sns.relplot(data=df.loc['P6','hard'], x='start_frame', y='cycle_distance', hue = 'subtech', aspect=2)

# %%
sns.relplot(data=df.loc['P7'], x='start_frame', y='cycle_distance', hue = 'intensity', aspect=2, row='subtech')

# %%
df['subtech'].unique()
# Out:
# array(['dp', 'diagonal', 'heringbone', 'dp-skate', 'dp-kick'],
#       dtype=object)

# %%
df = pd.read_csv(fp)
df['stop_frame']=df['stop_frame'].astype('int')
df
# Out:
#       Unnamed: 0 participant intensity   subtech  start_frame  stop_frame  \
# 0              0          P3      easy        dp         2459        2879
# 1              1          P3      easy        dp         2879        3316
# 2              2          P3      easy        dp         3316        3721
# 3              3          P3      easy        dp         3721        4141
# 4              4          P3      easy        dp         4141        4483
# ...          ...         ...       ...       ...          ...         ...
# 2275           2         P14      hard  dp-skate        15205       15460
# 2276           0         P14      hard  dp-skate        16435       16853
# 2277           0         P14      hard  dp-skate        18063       18275
# 2278           1         P14      hard  dp-skate        18275       18481
# 2279           2         P14      hard  dp-skate        18481       18678
#
#       cycle_time  cycle_distance  cycle_speed
# 0       1.750000        5.377489    11.062262
# 1       1.820833        5.560258    10.993279
# 2       1.687500        4.549126     9.704802
# 3       1.750000        5.137541    10.568656
# 4       1.425000        4.278466    10.808757
# ...          ...             ...          ...
# 2275    1.062500        0.000000     0.000000
# 2276    1.741667        0.000000     0.000000
# 2277    0.883333        0.000000     0.000000
# 2278    0.858333        0.000000     0.000000
# 2279    0.820833        0.000000     0.000000
#
# [2280 rows x 9 columns]

# %%
sns.catplot(data=df, y = 'cycle_distance', x = 'subtech', hue='participant', aspect = 2, row='intensity', kind='box')
