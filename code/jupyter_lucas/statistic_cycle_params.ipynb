# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
idx = pd.IndexSlice
sns.set_style("darkgrid")

# %%
fp = r'C:\Users\b1090197\OneDrive\Documents\XSki\xski\files\cycle_temp_params.csv'

df=pd.read_csv(fp, index_col=[3,4], header=[0])
df.index.rename("participant", level=0, inplace=True)
df.index.rename("intensity", level=1, inplace=True)
df=df[df.columns[1:]]

# %%
df
# Out:
#                        cycle_time   subtech  start_frame  cycle_distance  \
# participant intensity
# P3          easy         1.808333        dp        57011        5.716325
#             easy         1.791667        dp        57445        5.829350
#             easy         1.745833        dp        57875        6.386828
#             easy         1.741667        dp        58294        6.499256
#             easy         1.712500        dp        58712        6.379393
# ...                           ...       ...          ...             ...
# P14         hard         0.833333        dp        27553        0.000000
#             hard         0.975000        dp        27753        0.000000
#             hard         0.883333  dp-skate        18063        0.000000
#             hard         0.858333  dp-skate        18275        0.000000
#             hard         0.820833  dp-skate        18481        0.000000
#
#                        cycle_speed
# participant intensity
# ...

# %%
sns.relplot(data=df.loc['P6','hard'], x='start_frame', y='cycle_time', hue = 'subtech', aspect=2)
# Out:
# C:\Users\b1090197\AppData\Local\Temp\ipykernel_18008\2521928465.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   sns.relplot(data=df.loc['P6','hard'], x='start_frame', y='cycle_time', hue = 'subtech', aspect=2)

# %%
sns.relplot(data=df.loc['P6'], x='start_frame', y='cycle_speed', hue = 'subtech', aspect=2, row='intensity')

# %%
df['subtech'].unique()
# Out:
# array(['dp', 'diagonal', 'heringbone', 'dp-skate', 'dp-kick'],
#       dtype=object)
